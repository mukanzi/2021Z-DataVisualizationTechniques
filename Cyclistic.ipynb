# %% [markdown]
# <a href="https://colab.research.google.com/github/mukanzi/2021Z-DataVisualizationTechniques/blob/master/Cyclistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cyclistic Bike-Share Analysis.

# %%
#importing relevant packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Preparing the data.
#
# The first step is to prepare all the data and get them into one data frame for analysis of the data for the past year for different rides.
#
# I will create the dataframes individually and then combine them into one complete data frame.

# %%
#List of file paths to the csv files that have the datasets
file_path = ['/content/divvy_data/202201-divvy-tripdata.csv', '/content/divvy_data/202202-divvy-tripdata.csv', '/content/divvy_data/202203-divvy-tripdata.csv', '/content/divvy_data/202204-divvy-tripdata.csv','/content/divvy_data/202205-divvy-tripdata.csv','/content/divvy_data/202206-divvy-tripdata.csv','/content/divvy_data/202207-divvy-tripdata.csv','/content/divvy_data/202208-divvy-tripdata.csv','/content/divvy_data/202209-divvy-publictripdata.csv','/content/divvy_data/202210-divvy-tripdata.csv','/content/divvy_data/202211-divvy-tripdata.csv','/content/divvy_data/202212-divvy-tripdata.csv']


#creating and merging the dataframes into one complete data frame.
dfs =[]
for path in file_path:
  df = pd.read_csv(path)
  dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# The dataframes have been created succesfully and merged into one dataframe with approximately 5M rows of data. Looking at the shape of the dataframe.

# %%
combined_df.shape
# Out:
# (5667717, 13)

# %%
combined_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47  2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike  2022-01-10 08:41:56  2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40  2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike  2022-01-04 00:18:04  2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10  2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual
# 0  42.012560 -87.674367        casual
# 1  42.012560 -87.674367        casual
# 2  41.925330 -87.665800        member
# 3  41.961507 -87.671387        casual
# 4  41.884621 -87.627834        member

# %% [markdown]
# ##Preparing the data.
#
# This is the cleaning phase of the data analysis process.

# %%
combined_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
combined_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
combined_df['start_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave                               75237
# DuSable Lake Shore Dr & Monroe St                     41279
# DuSable Lake Shore Dr & North Blvd                    40090
# Michigan Ave & Oak St                                 39661
# Wells St & Concord Ln                                 37515
#                                                       ...
# Public Rack - Chappel Ave & 71st St                       1
# Public Rack - Pulaski Rd &amp; 65th St                    1
# Public Rack - Kedvale Ave & 63rd St                       1
# Public Rack - Oakley Ave & 50th Pl                        1
# Public Rack - Brighton Park Branch Chicago Library        1
# Name: start_station_name, Length: 1674, dtype: int64

# %%
#Converting started_at and ended_at to datetime objects.
combined_df['started_at'] = pd.to_datetime(combined_df['started_at'])
combined_df['ended_at'] = pd.to_datetime(combined_df['ended_at'])

# %%
combined_df['ride_legth'] = combined_df['ended_at']-combined_df['started_at']
combined_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual      ride_legth
# 0  42.012560 -87.674367        casual 0 days 00:02:57
# 1  42.012560 -87.674367        casual 0 days 00:04:21
# 2  41.925330 -87.665800        member 0 days 00:04:21
# 3  41.961507 -87.671387        casual 0 days 00:14:56
# 4  41.884621 -87.627834        member 0 days 00:06:02

# %%
#Extracting day of week.
combined_df['day_of_week'] = combined_df['started_at'].dt.day_of_week
combined_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual      ride_legth  day_of_week
# 0  42.012560 -87.674367        casual 0 days 00:02:57            3
# 1  42.012560 -87.674367        casual 0 days 00:04:21            0
# 2  41.925330 -87.665800        member 0 days 00:04:21            1
# 3  41.961507 -87.671387        casual 0 days 00:14:56            1
# 4  41.884621 -87.627834        member 0 days 00:06:02            3

# %%
#Mapping the actual day of the week from a number to text.
combined_df['week_day'] = combined_df['started_at'].dt.day_name()
combined_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual      ride_legth  day_of_week  week_day
# 0  42.012560 -87.674367        casual 0 days 00:02:57            3  Thursday
# 1  42.012560 -87.674367        casual 0 days 00:04:21            0    Monday
# 2  41.925330 -87.665800        member 0 days 00:04:21            1   Tuesday
# 3  41.961507 -87.671387        casual 0 days 00:14:56            1   Tuesday
# 4  41.884621 -87.627834        member 0 days 00:06:02            3  Thursday

# %%
#Checking for missing values
missing_values = combined_df.isnull()
print (missing_values.sum())
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    833064
# start_station_id      833064
# end_station_name      892742
# end_station_id        892742
# start_lat                  0
# start_lng                  0
# end_lat                 5858
# end_lng                 5858
# member_casual              0
# ride_legth                 0
# day_of_week                0
# week_day                   0
# dtype: int64

# %%
#Dropping missing values
clean_combined_df = combined_df.dropna(axis=0)
clean_combined_df.shape
# Out:
# (4369360, 16)

# %%
#Checking for missing values
missing_values = clean_combined_df.isnull()
print (missing_values.sum())
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# ride_legth            0
# day_of_week           0
# week_day              0
# dtype: int64

# %%
clean_combined_df.to_csv('cyclist_cleaned_data.csv')
